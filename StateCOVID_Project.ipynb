# %% [markdown]
# # The Effects of US Political Leanings on the Number of Covid-19 Cases

# %% [markdown]
# # Overview

# %% [markdown]
# Our research explores whether a particular US region’s overall political affiliation affects their total number of Covid-19 cases, exploring additional factors such as education ranking and Covid-19 safety guidelines. Using linear regression and multiple linear regression, we explored the relationship between these variables and found that there is a correlation between the political leaning and the safety policies of a US region and its overall amount of Covid cases.

# %% [markdown]
# # Group Members
#
# - Member 1
# - Member 2
# - Member 3
# - Huy Huynh
# - Member 5

# %% [markdown]
# # Research Question

# %% [markdown]
# How does the political affiliation of a particular US State impact the number of Coronavirus cases present in that state? Does a state’s overall educational level and adherence to CDC social distancing measures influence the residents’ inclination to follow such policies and thus the number of positive cases? Furthermore, within California and within Mississippi, how do two counties with opposing political leanings differ in the number of COVID-19 cases?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp; We are particularly interested in exploring this topic as college students who have had a unique experience as a result of COVID-19. This past year, we all experienced a worldwide lockdown, where we had to adjust to a new virtual lifestyle. No one expected the lockdown to last over eight months, and unfortunately the continuing spread of this disease is primarily due to American’s inability to collectively agree on a safe path forward. Debates over the effectiveness of masks and social distancing emerged all throughout the nation as some agreed to follow the measures and some protested against these measures.
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp; Additionally, the current presidential election is of utmost importance as the opposing parties have differing views and plans on how to handle the future with COVID-19. In such a crucial time period, most of our nation is divided over this issue, where citizens affiliated with their respective parties hear different news sources, and thus have differing opinions on what is just. With currently over 8.37 million COVID-19 cases and around 222,000 deaths in just the US (1), it is evident that thus far the virus has not been prevented from spreading. We realize the importance and relevance of this research topic because of how much the future of our country depends on the result of this upcoming election. Both parties hold such differing opinions and game plans for mitigating the virus, and it is the job of the elected president to properly handle the impact of the virus.
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp; Similar research connecting the rapid spread of Coronavirus and political party preferences has been done before. In Spring 2020, another Cogs 108 group focused their project on if colleges varying in political views had differing public messages and responses to COVID-19 (2). They came to the conclusion that contrary to their hypothesis, there really was no discernible discrepancy between the schools in the states that consistently voted blue, red, or swing states. We believe that they concluded this because they specifically looked at universities, which need to appear neutral in order to remain unbiased and professional towards students. We are instead not only considering each state as a whole, but also delving deeper into individual counties inside of one state, taking into account the fact that within a state there are many different opinions and not just one general political affiliation. Numerous articles have also been published on this topic, one specifically compiling survey data about how partisan differences affect attitudes towards different aspects of COVID-19 such as confidence in medical scientists, concern for public health, developing a vaccine, and amount of testing being done (3). This resource helped us shape our hypothesis because its data shows that those who identify as Republican or at least republican leaning, are distrusting of the idea that social distancing reduces the chance of contracting Coronavirus. Both the previous Cogs 108 project and this article will be beneficial to our project as we set out to answer our research question.
#
# References (include links):
# - 1) https://github.com/nytimes/covid-19-data/blob/master/live/us.csv
# - 2) https://github.com/COGS108/FinalProjects-Sp20/blob/master/FinalProject_group09.ipynb
# - 3) https://www.pewresearch.org/science/2020/06/03/partisan-differences-over-the-pandemic-response-are-growing/

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We hypothesize that if a particular state is more politically aligned with Republican values, then they may be more inclined to disregard CDC guidelines and therefore have a higher number of Covid-19 cases. We similarly hypothesize that a state with a higher overall education level and stricter adherence to Covid-19 safety measures will have a lower total number of positive cases. Because California is mainly Democratic and Mississippi is mainly Republican, we hypothesize that politically contrasting counties within these states will follow the overall trend of their state in terms of following safety measures.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# ### Dataset 1

# %% [markdown]
# - Name: NYT 2020 Presidential Election Results (US_election_results.csv)
# - Link to the dataset: https://www.nytimes.com/interactive/2020/11/03/us/elections/results-president.html?action=click&pgtype=Article&state=default&module=styln-elections-2020&region=TOP_BANNER&context=election_recirc
# - Number of observations: 55 rows
#
# This dataset is based off of the New York Times 2020 election results collected over the past month. Because there was accessible data we created our own csv file based off of the NYT election map and numbers provided.
#
# This dataset will be combined with the total US states Covid data as we will be comparing political affiliations of each state with its total number of Covid cases. We will also be combining this data with the 2019 populations by state data.

# %% [markdown]
# ### Dataset 2

# %% [markdown]
# - Name: NYT Covid 19 Data - States (us_state_cases.txt)
# - Link to the dataset: https://github.com/nytimes/covid-19-data/blob/master/us-states.csv
# - Number of observations: 55 rows
#
# This dataset is from the live NYT Covid-19 dataset and was collected on November 27, 2020. The data includes the total number of Covid cases and deaths per state as well as the confirmed cases and deaths.
#
# This dataset will be combined with the NYT 2020 US Election Results by State as we will be comparing the political affiliations of states to the number of Covid cases per state. We will also be combining this data with the 2019 populations by state data.

# %% [markdown]
# ### Dataset 3

# %% [markdown]
# - Name: Annual Estaimates of the Resident Population for the United States, Region, States, and Puerto Rico: April 1, 2010 to July 1, 2019 (us_state_populations.csv)
# - Link to the dataset: https://www2.census.gov/programs-surveys/popest/tables/2010-2019/state/totals/nst-est2019-01.xlsx
# - Number of observations: 60 rows
#
# This dataset is the US census data for the populations of all US states from 2010 to 2019. We will be using only the 2019 population data as it is the most recent and therefore can be used as a basis for percentage of Covid cases per state.
#
# This dataset will be combined with the NYT 2020 Election Results as well as the NYT Covid Data as we will be comparing the political affiliations of each state to their respective number of Covid cases, and by using the populations we can create frequencies rather than raw numbers.

# %% [markdown]
# ### Dataset 4

# %% [markdown]
# - Name: NYT Covid 19 Data - Counties (us_county_cases.txt)
# - Link to the dataset: https://github.com/nytimes/covid-19-data/blob/master/us-counties.csv
# - Number of observations: 3247 rows
#
# This dataset is from the live NYT Covid 19 dataset for US counties and was collected on November 27, 2020. The data includes the total number of covid cases and deaths per county as well as the confirmed cases and deaths.
#
# This dataset will be filtered into two separate dataframes that respectively have the California counties and Mississippi counties. They will then be combined with Covid cases per county and also the population per county for each state. We are looking at county level to delve deeper into our research question.

# %% [markdown]
# ### Dataset 5

# %% [markdown]
# - Name: NYT California Presidential Election Results  (CA_election_results.csv)
# - Link to the dataset: https://www.nytimes.com/interactive/2020/11/03/us/elections/results-california-president.html
# - Number of observations: 59 rows
#
# This dataset is from the NYT Presidential Election Results from 2020, specifically California's. There was no available dataset for us to use, so we created our own csv file using the California county data provided on the NYT website.
#
# This dataset will be combined with the California Covid Cases by County data as well as the 2019 populations of the California counties to hone in on smaller parts of the state.

# %% [markdown]
# ### Dataset 6

# %% [markdown]
# - Name: California Counties by Population (CA_county_pop.csv)
# - Link to the dataset: https://www.california-demographics.com/counties_by_population
# - Number of observations: 59 rows
#
# This dataset is from the California Demographics website that used the California 2019 Census Bureau data to provide the populations of each individual county in California.
#
# This dataset will be combined with the California Covid Cases by County data as well as the 2020 California Election Results by county to hone in on smaller parts of the state.

# %% [markdown]
# ### Dataset 7

# %% [markdown]
# - Name: NYT Mississippi Presidential Election Results (MS_election_results.csv)
# - Link to the dataset: https://www.nytimes.com/interactive/2020/11/03/us/elections/results-mississippi-president.html
# - Number of observations: 83 rows
#
# This dataset is from the NYT Presidential Election Results from 2020, specifically Mississippi's. There was no available dataset for us to use, so we created our own csv file using the Mississippi county data provided on the NYT website.
#
# This dataset will be combined with the Mississippi Covid Cases by County data as well as the 2019 populations of the Mississippi counties to hone in on smaller parts of the state.

# %% [markdown]
# ### Dataset 8

# %% [markdown]
# - Name: Mississippi Counties by Population (MS_county_pop.csv)
# - Link to the dataset: https://www.mississippi-demographics.com/counties_by_population
# - Number of observations: 83 rows
#
# This dataset is from the Mississippi Demographics website that used the Mississippi 2019 Census Bureau data to provide the populations of each individual county in Mississippi.
#
# This dataset will be combined with the Mississippi Covid Cases by County data as well as the 2020 Mississippi Election Results by county to hone in on smaller parts of the state.

# %% [markdown]
# ### Dataset 9

# %% [markdown]
# - Name: Best States For Education 2020 (state_education_ranking.csv)
# - Link to the dataset: https://worldpopulationreview.com/state-rankings/best-states-for-education
# - Number of observations: 51 rows
#
# This dataset is from the US News Education Rankings. This data provides an overall rank for each state and this rank was determined as a combination of both the state's overall higher
# education ranking and PreK-12 ranking.
#
# This dataset will be combined with the states' social distancing actions to see if a correlation exists between education level and willingness to follow safety measures.

# %% [markdown]
# ### Dataset 10

# %% [markdown]
# - Name: State Social Distancing Actions (state_social_distancing_actions.csv)
# - Link to the dataset: https://www.kff.org/coronavirus-covid-19/issue-brief/state-data-and-policy-actions-to-address-coronavirus/#stateleveldata
# - Number of observations: 92 rows
#
# This dataset is from the Kaiser Family Foundation website. It specifies the social distancing policies of each state and their current stance on certain recommended safety guidelines.
#
# This dataset will be combined with the states' education rankings to see if a correlation exists between education level and willingness to follow safety measures.

# %% [markdown]
# # Setup

# %%
# Imports 
# %matplotlib inline

import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import os 

import seaborn as sns
sns.set()
sns.set_context('talk')

import warnings
warnings.filterwarnings('ignore')

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

from sklearn.svm import SVC
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import classification_report, precision_recall_fscore_support

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## US States data (Datasets 1, 2, 3)

# %%
US_election = pd.read_csv("US_election_results")
US_election.head()
# Out:
#         State  Biden % votes  Trump % votes Biden # votes Trump # votes
# 0     Alabama          36.60          62.00       849,624     1,441,170
# 1      Alaska          43.00          53.10       153,551       189,457
# 2     Arizona          49.39          49.08     1,672,143     1,661,686
# 3    Arkansas          34.80          62.40       423,602       759,736
# 4  California          63.60          34.20    11,020,102     5,934,931

# %%
US_election = US_election.drop([8, 11, 36, 41, 50], axis=0)
US_election = US_election.reset_index(drop=True)
US_election = US_election[["State", "Biden % votes", "Trump % votes"]]
US_election.head()
# Out:
#         State  Biden % votes  Trump % votes
# 0     Alabama          36.60          62.00
# 1      Alaska          43.00          53.10
# 2     Arizona          49.39          49.08
# 3    Arkansas          34.80          62.40
# 4  California          63.60          34.20

# %% [markdown]
# We read in the US_election_results.csv file into a dataframe and then dropped the rows that were not part of the 50 states (DC, Puerto Rico, Northern Mariana Islands, Virgin Islands, and Guam). Then we reset the indices as they got messed up with the dropping of rows. After that we renamed the columns to make it more readable.

# %%
US_election["% Difference"] = US_election["Biden % votes"] - US_election["Trump % votes"]
US_election = US_election.sort_values('% Difference')
US_election.reset_index(inplace = True, drop = True)
US_election.head()
# Out:
#            State  Biden % votes  Trump % votes  % Difference
# 0        Wyoming           26.6           69.9         -43.3
# 1  West Virginia           29.7           68.6         -38.9
# 2   North Dakota           31.8           65.1         -33.3
# 3       Oklahoma           32.3           65.4         -33.1
# 4          Idaho           33.1           63.8         -30.7

# %% [markdown]
# Here we added a column with the percentage difference between Biden % votes and Trump % votes. This then gets plotted in the graph below.

# %%
plt.figure(figsize=(60,25))
colors = ["Biden" if c >= 0 else "Trump" for c in US_election['% Difference']]
sns.barplot(x="State", y="% Difference", hue=colors, data=US_election, palette=["crimson","mediumblue"]).set_title('2020 US Election Results', loc='center')

plt.legend(loc='upper left')
plt.tick_params(axis='x', rotation=90)
plt.ylabel("Percentage",labelpad=50)
plt.xlabel("State",labelpad=20)
sns.set(font_scale=4)

# %% [markdown]
# Above we have created a bar plot to show the distribution of the percentage of votes for Biden and Trump in each state. The states with a negative percentage had a higher proportion of conservative votes, whereas the states with the positive percentage difference had a higher proportion of democratic voters. We increased the figure size to an appropriate size, graphed the percentages, labeled each axis, turned the individual x axis labels to improve readability, and gave our graph a clear title.

# %%
US_covid_cases = pd.read_csv("us_state_cases.txt")
US_covid_cases = US_covid_cases[["state", "cases", "deaths"]]
US_covid_cases = US_covid_cases.rename(columns={"state": "State", "cases": "Cases", "deaths": "Deaths"})
US_covid_cases.head()
# Out:
#         State    Cases  Deaths
# 0     Alabama   242874    3572
# 1      Alaska    29940     113
# 2     Arizona   318695    6588
# 3    Arkansas   152625    2436
# 4  California  1181420   19033

# %%
US_covid_cases = US_covid_cases.drop([8, 11, 36, 41, 50], axis=0)
US_covid_cases = US_covid_cases.reset_index(drop=True)
US_covid_cases.head()
# Out:
#         State    Cases  Deaths
# 0     Alabama   242874    3572
# 1      Alaska    29940     113
# 2     Arizona   318695    6588
# 3    Arkansas   152625    2436
# 4  California  1181420   19033

# %%
US_data = US_covid_cases.merge(US_election, on="State")
US_data.head()
# Out:
#         State    Cases  Deaths  Biden % votes  Trump % votes  % Difference
# 0     Alabama   242874    3572          36.60          62.00        -25.40
# 1      Alaska    29940     113          43.00          53.10        -10.10
# 2     Arizona   318695    6588          49.39          49.08          0.31
# 3    Arkansas   152625    2436          34.80          62.40        -27.60
# 4  California  1181420   19033          63.60          34.20         29.40

# %% [markdown]
# We read in the us_state_cases.txt into a dataframe that now holds the Covid cases and deaths for all states in the US. Then we removed some unnecessary columns and renamed the remaining columns. Then we dropped the rows that were not included in the 50 states (DC, Northern Mariana Islands, Puerto Rico, Virgin Islands, and Guam). Then we reset the indices that got messed up after dropped the rows. Finally we merged this dataframe with the US_election dataframe above to create a US_data dataframe.

# %%
state_pop = pd.read_csv("us_state_populations.csv", header=1)
state_pop = state_pop.rename(columns={"Unnamed: 0":"State", "2019":"2019 Population"})
state_pop = state_pop[["State", "2019 Population"]]
state_pop = state_pop.drop([51, 52, 53, 54, 55, 56, 57], axis=0)
state_pop.head()
# Out:
#          State 2019 Population
# 0     .Alabama       4,903,185
# 1      .Alaska         731,545
# 2     .Arizona       7,278,717
# 3    .Arkansas       3,017,804
# 4  .California      39,512,223

# %%
def standardize_state(state):
    state = state.replace('.', '')
    state = state.strip()
    return state 

state_pop['State'] = state_pop['State'].apply(standardize_state)
state_pop.head()
# Out:
#         State 2019 Population
# 0     Alabama       4,903,185
# 1      Alaska         731,545
# 2     Arizona       7,278,717
# 3    Arkansas       3,017,804
# 4  California      39,512,223

# %%
US_data = state_pop.merge(US_data, on="State")
US_data.head()
# Out:
#         State 2019 Population    Cases  Deaths  Biden % votes  Trump % votes  \
# 0     Alabama       4,903,185   242874    3572          36.60          62.00
# 1      Alaska         731,545    29940     113          43.00          53.10
# 2     Arizona       7,278,717   318695    6588          49.39          49.08
# 3    Arkansas       3,017,804   152625    2436          34.80          62.40
# 4  California      39,512,223  1181420   19033          63.60          34.20
#
#    % Difference
# 0        -25.40
# 1        -10.10
# 2          0.31
# 3        -27.60
# 4         29.40

# %% [markdown]
# We read in the us_state_populations.csv into a state_pop dataframe and made the first row the header. Then we renamed columns for readability and removed the unnecessary columns from the table. After that we dropped the rows that were not important to our research question. Then we defined and applied a standardization function for the 'State' column as we needed it to be the same as our other dataframes so they could then be merged later on 'State'. Finally after the column was standardized, we merged it with the rest of our US_data to produce a dataframe with the 2019 population, Covid cases/deaths, percentage of Biden votes, and percentage of Trump votes for each state.

# %% [markdown]
# ## US Counties Data (Dataset 4)

# %%
county_covid_cases = pd.read_csv("us_county_cases.txt")
county_covid_cases = county_covid_cases[["state", "county", "cases", "deaths"]]
county_covid_cases = county_covid_cases.rename(columns={"state": "State", "county": "County", "cases": "Cases", "deaths": "Deaths"})

county_covid_cases.head()
# Out:
#      State   County  Cases  Deaths
# 0  Alabama  Autauga   2716    42.0
# 1  Alabama  Baldwin   8603    98.0
# 2  Alabama  Barbour   1171    10.0
# 3  Alabama     Bibb   1173    17.0
# 4  Alabama   Blount   2888    40.0

# %% [markdown]
# Above we have read in the us_county_cases.txt file into our county_covid_cases dataframe. Then we retained only the necessary columns and renamed those to be more readable.

# %% [markdown]
# ### CA data (Datasets 5 & 6)

# %%
CA_county_cases = county_covid_cases[county_covid_cases.State == 'California']
CA_county_cases = CA_county_cases.reset_index(drop=True)
CA_county_cases.head()
# Out:
#         State     County  Cases  Deaths
# 0  California    Alameda  28818   502.0
# 1  California     Alpine     41     0.0
# 2  California     Amador    487    16.0
# 3  California      Butte   3894    59.0
# 4  California  Calaveras    478    22.0

# %% [markdown]
# Here we are creating a separate dataframe to store only the California county Covid case data and this was taken from the county_covid_cases dataframe as that dataframe had the data for every single county in the United States. We then reset the index on this dataframe.

# %%
CA_election = pd.read_csv("CA_election_results.csv")
CA_election = CA_election[["County", "Biden % votes", "Trump % votes"]]
CA_election.head()
# Out:
#       County  Biden % votes  Trump % votes
# 0    Alameda           80.2           17.7
# 1     Alpine           64.3           32.3
# 2     Amador           36.6           60.9
# 3      Butte           49.4           47.8
# 4  Calaveras           36.8           61.0

# %%
CA_election["% Difference"] = CA_election["Biden % votes"] - CA_election["Trump % votes"]
CA_election = CA_election.sort_values('% Difference')
CA_election.reset_index(inplace = True, drop = True)
CA_election.head()
# Out:
#    County  Biden % votes  Trump % votes  % Difference
# 0  Lassen           23.5           74.7         -51.2
# 1   Modoc           26.5           71.7         -45.2
# 2  Tehama           31.1           66.6         -35.5
# 3  Shasta           32.5           65.3         -32.8
# 4   Glenn           35.3           62.7         -27.4

# %% [markdown]
# Here we are calculating the percent difference between Trump and Biden votes in each CA county. We are also sorting the dataframe by % Difference and resetting the index. We will then plot these values in the graph below.

# %%
plt.figure(figsize=(70,30))
colors = ["Biden" if c >= 0 else "Trump" for c in CA_election['% Difference']]
sns.barplot(x="County", y="% Difference", hue=colors, data=CA_election, palette=["crimson","mediumblue"]).set_title('2020 CA Election Results', loc='center')

plt.legend(loc='upper left')
plt.tick_params(axis='x', rotation=90)
plt.ylabel("Percentage",labelpad=50)
plt.xlabel("State",labelpad=30)
sns.set(font_scale=5)

# %% [markdown]
# This visualization shows the number of counties in California where the majority either voted for either Trump of Biden. The counties that have a negative percentage on the Left, are those that voted for Trump, and the proportion / how much of the majority can be seen as the greater the absolute value, the higher proportion of votes went to Trump. For Biden, the same logic applies, but in the positive direction.

# %%
CA_data = CA_county_cases.merge(CA_election, on="County")
CA_data.head()
# Out:
#         State     County  Cases  Deaths  Biden % votes  Trump % votes  \
# 0  California    Alameda  28818   502.0           80.2           17.7
# 1  California     Alpine     41     0.0           64.3           32.3
# 2  California     Amador    487    16.0           36.6           60.9
# 3  California      Butte   3894    59.0           49.4           47.8
# 4  California  Calaveras    478    22.0           36.8           61.0
#
#    % Difference
# 0          62.5
# 1          32.0
# 2         -24.3
# 3           1.6
# 4         -24.2

# %% [markdown]
# Here we read in the CA_election_results.csv and stored the data in the CA_election dataframe before dropping the columns we felt were unnecessary for our research question. We also merged this dataframe with the CA_county_cases dataframe above to create one dataframe that has California's data.

# %%
CA_pop = pd.read_csv("CA_county_pop.csv")
CA_pop = CA_pop.rename(columns={"Population":"2019 Population"})
CA_pop = CA_pop[["County", "2019 Population"]]
CA_pop = CA_pop.sort_values(by=['County'])
CA_pop = CA_pop.reset_index(drop=True)
CA_pop.head()
# Out:
#              County 2019 Population
# 0    Alameda County       1,671,329
# 1     Alpine County           1,129
# 2     Amador County          39,752
# 3      Butte County         219,186
# 4  Calaveras County          45,905

# %%
def standardize_county(county):
    county = county.replace('County', '')
    county = county.strip()
    return county 

CA_pop['County'] = CA_pop['County'].apply(standardize_county)
CA_pop.head()
# Out:
#       County 2019 Population
# 0    Alameda       1,671,329
# 1     Alpine           1,129
# 2     Amador          39,752
# 3      Butte         219,186
# 4  Calaveras          45,905

# %%
CA_data = CA_pop.merge(CA_data, on="County")
CA_data.head()
# Out:
#       County 2019 Population       State  Cases  Deaths  Biden % votes  \
# 0    Alameda       1,671,329  California  28818   502.0           80.2
# 1     Alpine           1,129  California     41     0.0           64.3
# 2     Amador          39,752  California    487    16.0           36.6
# 3      Butte         219,186  California   3894    59.0           49.4
# 4  Calaveras          45,905  California    478    22.0           36.8
#
#    Trump % votes  % Difference
# 0           17.7          62.5
# 1           32.3          32.0
# 2           60.9         -24.3
# 3           47.8           1.6
# 4           61.0         -24.2

# %% [markdown]
# Next, we read in the CA_county_pop.csv into the CA_pop dataframe. We renamed the columns and dropped the ones we did not need. Then we sorted the values alphabetically by county and reset the indices. Then we defined a function to standardize the 'County' column of the dataframe as we needed to merge it with the CA_data dataframe on 'County'. Once the column was standardized we merged the two dataframes.

# %% [markdown]
# ### MS data (Datasets 7 & 8)

# %%
MS_county_cases = county_covid_cases[county_covid_cases.State == 'Mississippi']
MS_county_cases = MS_county_cases.reset_index(drop=True)
MS_county_cases.head()
# Out:
#          State  County  Cases  Deaths
# 0  Mississippi   Adams   1411    50.0
# 1  Mississippi  Alcorn   1496    28.0
# 2  Mississippi   Amite    531    14.0
# 3  Mississippi  Attala   1122    34.0
# 4  Mississippi  Benton    491    17.0

# %% [markdown]
# Here we are creating a separate dataframe to store only the Mississippi county Covid case data and this was taken from the county_covid_cases dataframe as that dataframe had the data for every single county in the United States. We then reset the index on this dataframe.

# %%
MS_election = pd.read_csv("MS_election_results.csv")
MS_election = MS_election[["County", "Biden % votes", "Trump % votes"]]
MS_election.head()
# Out:
#    County  Biden % votes  Trump % votes
# 0   Adams           57.5           41.4
# 1  Alcorn           17.6           81.1
# 2   Amite           36.4           62.5
# 3  Attala           40.1           58.6
# 4  Benton           39.1           59.9

# %%
MS_election["% Difference"] = MS_election["Biden % votes"] - MS_election["Trump % votes"]
MS_election = MS_election.sort_values('% Difference')
MS_election.reset_index(inplace = True, drop = True)
MS_election.head()
# Out:
#        County  Biden % votes  Trump % votes  % Difference
# 0      George           11.0           87.8         -76.8
# 1    Itawamba           11.5           87.2         -75.7
# 2  Tishomingo           11.6           86.7         -75.1
# 3      Greene           16.6           82.4         -65.8
# 4       Union           17.0           81.8         -64.8

# %% [markdown]
# Here, we are creating a new column for the percent difference between Trump and Biden votes, and then we are sorting by county for % difference and resetting the index. These values will be plotted in the graph below.

# %%
plt.figure(figsize=(75,30))
colors = ["Biden" if c >= 0 else "Trump" for c in MS_election['% Difference']]
sns.barplot(x="County", y="% Difference", hue=colors, data=MS_election, palette=["crimson","mediumblue"]).set_title('2020 CA Election Results', loc='center')

plt.legend(loc='upper left')
plt.tick_params(axis='x', rotation=90)
plt.ylabel("Percentage",labelpad=50)
plt.xlabel("State",labelpad=20)
sns.set(font_scale=5)

# %% [markdown]
# Above we have created a graph to show the distribution of the percentage of votes for Biden and Trump in each county in Mississippi. We increased the figure size to be an appropriate size, graphed the percentages, labeled each axis, turned the individual x axis labels for readability, chose intuitive colors, and gave the graph a clear title.

# %%
MS_data = MS_county_cases.merge(MS_election, on="County")
MS_data.head()
# Out:
#          State  County  Cases  Deaths  Biden % votes  Trump % votes  \
# 0  Mississippi   Adams   1411    50.0           57.5           41.4
# 1  Mississippi  Alcorn   1496    28.0           17.6           81.1
# 2  Mississippi   Amite    531    14.0           36.4           62.5
# 3  Mississippi  Attala   1122    34.0           40.1           58.6
# 4  Mississippi  Benton    491    17.0           39.1           59.9
#
#    % Difference
# 0          16.1
# 1         -63.5
# 2         -26.1
# 3         -18.5
# 4         -20.8

# %% [markdown]
# Here we read in the MS_election_results.csv and stored the data in the MS_election dataframe before dropping the columns we felt were unnecessary for our research question. We also merged this dataframe with the MS_county_cases dataframe above to create one dataframe that has Mississippi's data.

# %%
MS_pop = pd.read_csv("MS_county_pop.csv")
MS_pop = MS_pop.rename(columns={"Population":"2019 Population"})
MS_pop = MS_pop[["County", "2019 Population"]]
MS_pop = MS_pop.sort_values(by=['County'])
MS_pop = MS_pop.reset_index(drop=True)
MS_pop.head()
# Out:
#           County 2019 Population
# 0   Adams County          30,693
# 1  Alcorn County          36,953
# 2   Amite County          12,297
# 3  Attala County          18,174
# 4  Benton County           8,259

# %%
MS_pop['County'] = MS_pop['County'].apply(standardize_county)
MS_pop.head()
# Out:
#    County 2019 Population
# 0   Adams          30,693
# 1  Alcorn          36,953
# 2   Amite          12,297
# 3  Attala          18,174
# 4  Benton           8,259

# %%
MS_data = MS_pop.merge(MS_data, on="County")
MS_data.head()
# Out:
#    County 2019 Population        State  Cases  Deaths  Biden % votes  \
# 0   Adams          30,693  Mississippi   1411    50.0           57.5
# 1  Alcorn          36,953  Mississippi   1496    28.0           17.6
# 2   Amite          12,297  Mississippi    531    14.0           36.4
# 3  Attala          18,174  Mississippi   1122    34.0           40.1
# 4  Benton           8,259  Mississippi    491    17.0           39.1
#
#    Trump % votes  % Difference
# 0           41.4          16.1
# 1           81.1         -63.5
# 2           62.5         -26.1
# 3           58.6         -18.5
# 4           59.9         -20.8

# %% [markdown]
# Next, we read in the MS_county_pop.csv into the MS_pop dataframe. We renamed the columns and dropped the ones we did not need. Then we sorted the values alphabetically by county and reset the indices. Then we used the previously defined function to standardize the 'County' column of the dataframe as we needed to merge it with the MS_data dataframe on 'County'. Once the column was standardized we merged the two dataframes.

# %% [markdown]
# ## State Education Level (Dataset 9)

# %%
state_edu = pd.read_csv("state_education_ranking.csv")
state_edu = state_edu[["State", "overallRank"]]
state_edu = state_edu.rename(columns={"overallRank":"Education Rank"})

state_edu.head()
# Out:
#            State  Education Rank
# 0  Massachusetts               1
# 1     New Jersey               2
# 2        Florida               3
# 3     Washington               4
# 4  New Hampshire               5

# %% [markdown]
# Here we read in the state_education_ranking.csv into the state_edu dataframe. We kept the overall rank column and renamed it to be "Education Rank" to clarify exactly what the rank is for each state. To keep it easy in terms of readability, we kept the rank in a table format.

# %%
US_edu_and_election = US_election.merge(state_edu, on="State")
US_edu_and_election = US_edu_and_election.sort_values('Education Rank')
US_edu_and_election.reset_index(inplace = True, drop = True)

US_edu_and_election.head()
# Out:
#            State  Biden % votes  Trump % votes  % Difference  Education Rank
# 0  Massachusetts           65.3           32.4          32.9               1
# 1     New Jersey           57.1           41.2          15.9               2
# 2        Florida           47.9           51.2          -3.3               3
# 3     Washington           58.4           39.0          19.4               4
# 4  New Hampshire           52.8           45.5           7.3               5

# %%
def trump_or_biden(difference):
    if difference > 0:
        vote = 'Trump'
    elif difference < 0:
        vote = 'Biden'
    return vote

US_edu_and_election["% Difference"] = US_edu_and_election['% Difference'].apply(trump_or_biden)
US_edu_and_election.head()
# Out:
#            State  Biden % votes  Trump % votes % Difference  Education Rank
# 0  Massachusetts           65.3           32.4        Trump               1
# 1     New Jersey           57.1           41.2        Trump               2
# 2        Florida           47.9           51.2        Biden               3
# 3     Washington           58.4           39.0        Trump               4
# 4  New Hampshire           52.8           45.5        Trump               5

# %% [markdown]
# Above, we standardized the "Difference column" for each state, as a way to give a clear cut answer on what candidate each state ended up voting for, alongside the state's national rank, with 1 being the best and 50 being the worst.

# %%
ax = sns.boxplot(x='% Difference', y = 'Education Rank', data=US_edu_and_election, whis=np.inf, palette=["crimson","mediumblue"] )
ax = sns.stripplot(x='% Difference', y = 'Education Rank', data = US_edu_and_election, palette=["crimson","mediumblue"], jitter=True) 
ax.invert_yaxis()
ax.set_title('Education Level and Candidate Votes')
# Out:
# Text(0.5, 1.0, 'Education Level and Candidate Votes')

# %% [markdown]
# In the above two cells, the values in the '2019 Population' column were standardized, then the percentage of Covid cases per state was calculated using the 2019 Population as well as the raw number of Covid cases. This became a separate column in the dataframe.

# %% [markdown]
# ## State Social Distancing Policies (Dataset 10)

# %%
policies = pd.read_csv("state_social_distancing_actions.csv")
policies.head()
# Out:
#         Location                                Status of Reopening  \
# 0  United States  Proceeding (15); Paused (3); New Restrictions ...
# 1        Alabama                                             Paused
# 2         Alaska                          Proceeding with Reopening
# 3        Arizona                           New Restrictions Imposed
# 4       Arkansas                                             Paused
#
#                                   Stay at Home Order  \
# 0  Original Stay at Home Order in Place (1); Stay...
# 1                                             Lifted
# 2                                             Lifted
# 3                                             Lifted
# 4                                                  -
#
#                   Mandatory Quarantine for Travelers  \
# 0  Original Traveler Quarantine Mandate in Place ...
# 1                                                  -
# 2                                All Travelers (New)
# ...

# %%
#Clean Up Column Names. Remove the Footnotes Column
policies = policies.drop(columns=['Footnotes'])
policies.columns = ['State', 'Reopening', 'Stay at Home', 'Traveling Mandatory Quarantine', 'Business Closures', 'Gathering Ban',
                      'Restaurant Limits', 'Bar Closures', 'Mask Requirements', 'State of Emergency']
policies = policies.drop([0], axis=0)
policies = policies.reset_index(drop=True)
policies = policies.drop(policies.index[51:90])
policies.head()
# Out:
#         State                  Reopening Stay at Home  \
# 0     Alabama                     Paused       Lifted
# 1      Alaska  Proceeding with Reopening       Lifted
# 2     Arizona   New Restrictions Imposed       Lifted
# 3    Arkansas                     Paused            -
# 4  California  Proceeding with Reopening    Statewide
#
#   Traveling Mandatory Quarantine  \
# 0                              -
# 1            All Travelers (New)
# 2                         Lifted
# 3                         Lifted
# 4                              -
#
#                                    Business Closures  \
# 0  All Non-Essential Businesses Permitted to Reop...
# 1   All Non-Essential Businesses Permitted to Reopen
# 2                    New Business Closures or Limits
# 3                                                  -
# 4                    New Business Closures or Limits
#
#                             Gathering Ban  \
# 0                                  Lifted
# ...

# %% [markdown]
# Here we first read state_social_distancing_actions.csv into the policies dataframe. Next, we dropped the columns we did not need, and renamed the other columns for maximum readability. Then we dropped the rows of the dataframe that did not have necessary information about the states and reset the indices.

# %%
policies['Reopening'].unique()
# Out:
# array(['Paused', 'Proceeding with Reopening', 'New Restrictions Imposed',
#        'Reopened'], dtype=object)

# %%
policies['Reopening'] = policies['Reopening'].astype(str)
def standardize_reopening(string):
    string = string.replace('Proceeding with Reopening', 'Reopening')
    string = string.replace('New Restrictions Imposed', 'New Restrictions')
    return string 

policies['Reopening'] = policies['Reopening'].apply(standardize_reopening)
policies['Reopening'].unique()
# Out:
# array(['Paused', 'Reopening', 'New Restrictions', 'Reopened'],
#       dtype=object)

# %%
policies['Stay at Home'].unique()
# Out:
# array(['Lifted', '-', 'Statewide', 'Rolled Back to High Risk Groups'],
#       dtype=object)

# %%
policies['Stay at Home'] = policies['Stay at Home'].astype(str)
def standardize_stayHome(string):
    string = string.replace('-', 'nan')
    string = string.replace('Rolled Back to High Risk Groups', 'High Risk Stay Home')    
    return string 

policies['Stay at Home'] = policies['Stay at Home'].apply(standardize_stayHome)
policies['Stay at Home'].unique()
# Out:
# array(['Lifted', 'nan', 'Statewide', 'High Risk Stay Home'], dtype=object)

# %%
policies['Traveling Mandatory Quarantine'].unique()
# Out:
# array(['-', 'All Travelers (New)', 'Lifted', 'From Certain States (New)',
#        'All Travelers', 'From Certain States',
#        'Rolled Back to International Travel',
#        'Rolled Back to Certain States'], dtype=object)

# %%
policies['Traveling Mandatory Quarantine'] = policies['Traveling Mandatory Quarantine'].astype(str)
def standardize_travel(string):
    string = string.replace('-', 'nan')
    string = string.replace('All Travelers (New)', 'All Travelers')    
    string = string.replace('From Certain States (New)', 'From Certain States')    
    string = string.replace('Rolled Back to International Travel', 'No International Travel') 
    string = string.replace('Rolled Back to Certain States', 'From Certain States') 
    return string 

policies['Traveling Mandatory Quarantine'] = policies['Traveling Mandatory Quarantine'].apply(standardize_travel)
policies['Traveling Mandatory Quarantine'].unique()
# Out:
# array(['nan', 'All Travelers', 'Lifted', 'From Certain States',
#        'No International Travel'], dtype=object)

# %%
policies['Business Closures'].unique()
# Out:
# array(['All Non-Essential Businesses Permitted to Reopen with Reduced Capacity',
#        'All Non-Essential Businesses Permitted to Reopen',
#        'New Business Closures or Limits', '-',
#        'Some Non-Essential Businesses Permitted to Reopen with Reduced Capacity',
#        'Some Non-Essential Businesses Permitted to Reopen'], dtype=object)

# %%
policies['Business Closures'] = policies['Business Closures'].astype(str)
def standardize_businesses(string):
    string = string.replace("All Non-Essential Businesses Permitted to Reopen with Reduced Capacity", "Reopen Non Essential Businesses; Reduced Capacity")    
    string = string.replace("All Non-Essential Businesses Permitted to Reopen", "Reopen Non Essential Businesses")    
    string = string.replace("New Business Closures or Limits", "Close Business") 
    string = string.replace("Some Non-Essential Businesses Permitted to Reopen with Reduced Capacity", "Reopen Non Essential Businesses; Reduced Capacity") 
    string = string.replace("Some Non-Essential Businesses Permitted to Reopen", "Reopen Non Essential Businesses") 
    string = string.replace('-', 'nan')
    return string 

policies['Business Closures'] = policies['Business Closures'].apply(standardize_businesses)
policies['Business Closures'].unique()
# Out:
# array(['Reopen Non Essential Businesses; Reduced Capacity',
#        'Reopen Non Essential Businesses', 'Close Business', 'nan'],
#       dtype=object)

# %%
policies['Gathering Ban'].unique()
# Out:
# array(['Lifted', 'New Limit on Large Gatherings in Place',
#        'All Gatherings Prohibited', 'Expanded Limit to 25 or Fewer',
#        'Expanded Limit to Greater Than 25'], dtype=object)

# %%
policies['Gathering Ban'] = policies['Gathering Ban'].astype(str)
def standardize_gatherings(string):
    string = string.replace('New Limit on Large Gatherings in Place', 'Limit Large Gatherings')    
    string = string.replace('All Gatherings Prohibited', 'No Gathering')    
    string = string.replace('Expanded Limit to 25 or Fewer', '25 or Less') 
    string = string.replace('Expanded Limit to Greater Than 25', '25 or More Ok') 
    return string 

policies['Gathering Ban'] = policies['Gathering Ban'].apply(standardize_gatherings)
policies['Gathering Ban'].unique()
# Out:
# array(['Lifted', 'Limit Large Gatherings', 'No Gathering', '25 or Less',
#        '25 or More Ok'], dtype=object)

# %%
policies['Restaurant Limits'].unique()
# Out:
# array(['Reopened to Dine-in Service', 'New Service Limits',
#        'Reopened to Dine-in Service with Capacity Limits',
#        'Newly Closed to Indoor Dining', '-'], dtype=object)

# %%
policies['Restaurant Limits'] = policies['Restaurant Limits'].astype(str)
def standardize_restaurants(string):
    string = string.replace('Reopened to Dine-in Service with Capacity Limits', 'Dine In Allowed; Limited Capacity') 
    string = string.replace('Reopened to Dine-in Service', 'Dine In Is Allowed')    
    string = string.replace('New Service Limits', 'Service Limits')    
    string = string.replace('Newly Closed to Indoor Dining', 'No Indoor Dining') 
    string = string.replace('-','nan')
    return string 

policies['Restaurant Limits'] = policies['Restaurant Limits'].apply(standardize_restaurants)
policies['Restaurant Limits'].unique()
# Out:
# array(['Dine In Is Allowed', 'Service Limits',
#        'Dine In Allowed; Limited Capacity', 'No Indoor Dining', 'nan'],
#       dtype=object)

# %%
policies['Bar Closures'].unique()
# Out:
# array(['Reopened', 'Newly Closed', 'Closed', 'New Service Limits'],
#       dtype=object)

# %%
policies['Bar Closures'] = policies['Bar Closures'].astype(str)
def standardize_bars(string):
    string = string.replace('Newly Closed', 'Closed')    
    string = string.replace('New Service Limits', 'Service Limits')
    return string 

policies['Bar Closures'] = policies['Bar Closures'].apply(standardize_bars)
policies['Bar Closures'].unique()
# Out:
# array(['Reopened', 'Closed', 'Service Limits'], dtype=object)

# %%
policies['Mask Requirements'].unique()
# Out:
# array(['Required for General Public', 'Required for Certain Employees',
#        'Required for Certain Employees; Allows Local Officials to Require for General Public',
#        '-', 'Allows Local Officials to Require for General Public'],
#       dtype=object)

# %%
policies['Mask Requirements'] = policies['Mask Requirements'].astype(str)
def standardize_masks(string):
    string = string.replace('Required for General Public', 'Required for All')    
    string = string.replace('Required for Certain Employees', 'Required for Employees')
    string = string.replace('Required for Certain Employees; Allows Local Officials to Require for General Public', 'Required for Employees, Local Officials Choose for Public')
    string = string.replace('Allows Local Officials to Require for General Public', 'Local Officials Choose for Public')
    string = string.replace('-','nan')
    return string 

policies['Mask Requirements'] = policies['Mask Requirements'].apply(standardize_masks)
policies['Mask Requirements'].unique()
# Out:
# array(['Required for All', 'Required for Employees',
#        'Required for Employees; Local Officials Choose for Public', 'nan',
#        'Local Officials Choose for Public'], dtype=object)

# %%
policies['State of Emergency'].unique()
# Out:
# array(['Yes'], dtype=object)

# %% [markdown]
# Finally we printed out the unique values of every column in the policies dataframe and standardized them all so they can now be easily read and understood, which makes them much easier to work with. For each column we defined a function to aid in the standardization of it all.

# %%
policies.head()
# Out:
#         State         Reopening Stay at Home Traveling Mandatory Quarantine  \
# 0     Alabama            Paused       Lifted                            nan
# 1      Alaska         Reopening       Lifted                  All Travelers
# 2     Arizona  New Restrictions       Lifted                         Lifted
# 3    Arkansas            Paused          nan                         Lifted
# 4  California         Reopening    Statewide                            nan
#
#                                    Business Closures           Gathering Ban  \
# 0  Reopen Non Essential Businesses; Reduced Capacity                  Lifted
# 1                    Reopen Non Essential Businesses                  Lifted
# 2                                     Close Business  Limit Large Gatherings
# 3                                                nan                  Lifted
# 4                                     Close Business            No Gathering
#
# ...

# %%
def quantify_Reopening(string):
    #state of reopening
    string = string.replace('nan', '0')
    string = string.replace('Reopened', '1')
    string = string.replace('Reopening', '2')
    string = string.replace('New Restrictions', '3')
    string = string.replace('Paused', '4')
    return int(string)

def quantify_StayAtHome(string):
    #stay at home
    string = string.replace('nan', '0')
    string = string.replace('Lifted', '1')
    string = string.replace('High Risk Stay Home', '2')
    string = string.replace('Statewide', '3')
    return int(string)

def quantify_Traveling(string):
    #traveling
    string = string.replace('nan', '0')
    string = string.replace('Lifted', '1')
    string = string.replace('No International Travel', '2')
    string = string.replace('From Certain States', '2')
    string = string.replace('All Travelers', '3')
    return int(string)
    
def quantify_Business(string):
    #business closures 
    string = string.replace('nan', '0')
    string = string.replace('Reopen Non Essential Businesses; Reduced Capacity', '2')
    string = string.replace('Reopen Non Essential Businesses', '1')
    string = string.replace('Close Business', '3')
    return int(string)

def quantify_Gathering(string):
    #gathering ban
    string = string.replace('Lifted', '1')
    string = string.replace('25 or More Ok', '2')
    string = string.replace('25 or Less', '3')
    string = string.replace('Limit Large Gatherings', '4')
    string = string.replace('No Gathering', '5')
    return int(string)

def quantify_Restaurants(string):
    #restaurant limits
    string = string.replace('nan', '0')
    string = string.replace('Dine In Is Allowed', '1')
    string = string.replace('Dine In Allowed; Limited Capacity', '2')
    string = string.replace('Service Limits', '3')
    string = string.replace('No Indoor Dining', '4')
    return int(string)
    
def quantify_Bars(string):
    #bar closures
    string = string.replace('Reopened', '1')
    string = string.replace('Service Limits', '2')
    string = string.replace('Closed', '3')
    return int(string)
    
def quantify_Masks(string):
    #mask requirements
    string = string.replace('nan', '0')
    string = string.replace('Required for Employees; Local Officials Choose for Public', '3')
    string = string.replace('Local Officials Choose for Public', '1')
    string = string.replace('Required for Employees', '2')
    string = string.replace('Required for All', '4')
    return int(string)

# %%
policies['SafetyScore'] = policies['Reopening'].apply(quantify_Reopening) + policies['Stay at Home'].apply(quantify_StayAtHome) + policies['Traveling Mandatory Quarantine'].apply(quantify_Traveling) + policies['Business Closures'].apply(quantify_Business) + policies['Gathering Ban'].apply(quantify_Gathering) + policies['Restaurant Limits'].apply(quantify_Restaurants) + policies['Bar Closures'].apply(quantify_Bars) + policies['Mask Requirements'].apply(quantify_Masks)
policies.head()
# Out:
#         State         Reopening Stay at Home Traveling Mandatory Quarantine  \
# 0     Alabama            Paused       Lifted                            nan
# 1      Alaska         Reopening       Lifted                  All Travelers
# 2     Arizona  New Restrictions       Lifted                         Lifted
# 3    Arkansas            Paused          nan                         Lifted
# 4  California         Reopening    Statewide                            nan
#
#                                    Business Closures           Gathering Ban  \
# 0  Reopen Non Essential Businesses; Reduced Capacity                  Lifted
# 1                    Reopen Non Essential Businesses                  Lifted
# 2                                     Close Business  Limit Large Gatherings
# 3                                                nan                  Lifted
# 4                                     Close Business            No Gathering
#
# ...

# %% [markdown]
# Above we assigned numerical values to each unique string in every column of the policies dataframe. They correspond to the safety guidelines where the lower value indicates an unsafe policy, and a higher value indicates a more restricted policy. We then added up these values and created an overall Safety Score for every state.

# %% [markdown]
# Here we will be creating a choropleth map to aid in visualizing the variety of safety scores between all of the states.

# %%
layout = dict(title='Safety score map', 
              geo = dict(scope = 'usa', projection=dict(type='albers usa'), showlakes = True, lakescolor = 'rgb(66,165,245)',),)
layout
# Out:
# {'title': 'Safety score map',
#  'geo': {'scope': 'usa',
#   'projection': {'type': 'albers usa'},
#   'showlakes': True,
#   'lakescolor': 'rgb(66,165,245)'}}

# %%
path = os.getcwd()
print(path)
# Out:
# /home/usuresh/group012_fa20

# %%
USA = gpd.read_file(path +"/cb_2018_us_state_20m.shp",SHAPE_RESTORE_SHX=True)
USA = USA[(USA['NAME']!='ak') & (USA['NAME']!='hi')]

USA = USA[["NAME", "geometry"]]
USA = USA.rename(columns={"NAME":"State"})
USA = USA.sort_values(by=['State'])
USA = USA.reset_index(drop=True)
USA.head()
# Out:
#         State                                           geometry
# 0     Alabama  POLYGON ((-88.46866 31.89386, -88.46866 31.933...
# 1      Alaska  MULTIPOLYGON (((179.48132 51.97530, 179.58286 ...
# 2     Arizona  POLYGON ((-114.79968 32.59362, -114.80939 32.6...
# 3    Arkansas  POLYGON ((-94.61792 36.49941, -94.36120 36.499...
# 4  California  MULTIPOLYGON (((-118.59397 33.46720, -118.4847...

# %%
# dropped Puerto Rico and Alaska to zoom in on graph
USA = USA.drop([1, 39])
USA = USA.reset_index(drop=True)
USA.head()
# Out:
#         State                                           geometry
# 0     Alabama  POLYGON ((-88.46866 31.89386, -88.46866 31.933...
# 1     Arizona  POLYGON ((-114.79968 32.59362, -114.80939 32.6...
# 2    Arkansas  POLYGON ((-94.61792 36.49941, -94.36120 36.499...
# 3  California  MULTIPOLYGON (((-118.59397 33.46720, -118.4847...
# 4    Colorado  POLYGON ((-109.05996 38.49999, -109.05151 39.1...

# %%
state_safeties = policies.groupby('State')['SafetyScore'].agg(['mean', 'count'])
state_safeties = USA.merge(state_safeties, right_on="State", left_on="State")
state_safeties = state_safeties.sort_values('State')
state_safeties.head()
# Out:
#         State                                           geometry  mean  count
# 0     Alabama  POLYGON ((-88.46866 31.89386, -88.46866 31.933...    14      1
# 1     Arizona  POLYGON ((-114.79968 32.59362, -114.80939 32.6...    21      1
# 2    Arkansas  POLYGON ((-94.61792 36.49941, -94.36120 36.499...    13      1
# 3  California  MULTIPOLYGON (((-118.59397 33.46720, -118.4847...    22      1
# 4    Colorado  POLYGON ((-109.05996 38.49999, -109.05151 39.1...    18      1

# %%
fig, ax = plt.subplots(1, 1,figsize=(800,5))
legend = {'label':" StateScore", 'orientation': "horizontal"}
state_safeties.plot(column="mean", ax=ax, legend=True, legend_kwds=legend, cmap="PuBu")
plt.title("Safety Score Visual")
# Out:
# Text(0.5, 1.0, 'Safety Score Visual')

# %% [markdown]
# This choropleth map displays the safety scores of each state, with the darker values indicating a higher safety score. The darker states have stricter Covid safety regulations. For visual purposes, we removed Alaska from the diagram as it contained an island that extended the map and made it difficult to visualize the remaining states. Alaska has a low safety score of 12.

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# ### Political Rankings at US State and County levels

# %%
def political_rank(difference):
    # neutral -- only a 5% difference 
    if difference <= 5 and difference >= -5:
        rank = 3
    # 10% difference -- positive, mildly Democratic 
    elif difference > 5 and difference <= 10:
        rank = 2
    # >10% difference -- positive, mainly Democratic 
    elif difference > 10:
        rank = 1
    # 10% difference -- negative, mildly Republican 
    elif difference < -5 and difference >= -10:
        rank = 4
    # >-10% difference -- negative, mainly Republican 
    elif difference < -10:
        rank = 5
    return rank

# %% [markdown]
# The above cell is a defined function that creates a political rank for each state based on the percentage difference column of the dataframe. The percentage difference is calculated by subtracting the 'Trump % votes' column from the 'Biden % votes' column. Then we defined a 5 level scale to determine what the individual states' political leanings were based off of the 2020 US Election. If only a difference between positive and negative 5% existed between the two candidates, the state was ranked a 3. If a positive difference between 5 and 10 existed, then the state was deemed mildly democratic and ranked a 2. If a positive percentage of more than 10 existed, then the state was considered primarily democratic and ranked as a 1. If the percentage difference fell between -5% and -10% the state was seen as mildly republican and ranked at a 4. Finally if the percentage difference fell past -10% the state was considered primarily republican and ranked as a 5.

# %%
US_data["% Difference"] = US_data["Biden % votes"] - US_data["Trump % votes"]
US_data['PoliticalRank'] = US_data['% Difference'].apply(political_rank)
US_data.head()
# Out:
#         State 2019 Population    Cases  Deaths  Biden % votes  Trump % votes  \
# 0     Alabama       4,903,185   242874    3572          36.60          62.00
# 1      Alaska         731,545    29940     113          43.00          53.10
# 2     Arizona       7,278,717   318695    6588          49.39          49.08
# 3    Arkansas       3,017,804   152625    2436          34.80          62.40
# 4  California      39,512,223  1181420   19033          63.60          34.20
#
#    % Difference  PoliticalRank
# 0        -25.40              5
# 1        -10.10              5
# 2          0.31              3
# 3        -27.60              5
# 4         29.40              1

# %% [markdown]
# Here the percentage difference between 'Biden % votes' and 'Trump % votes' was created for every US state, and using that and the defined function above a rank column was created to hold the political ranking of each state.

# %% [markdown]
# ### CA Political Ranks

# %%
CA_data["% Difference"] = CA_data["Biden % votes"] - CA_data["Trump % votes"]
CA_data['PoliticalRank'] = CA_data['% Difference'].apply(political_rank)
CA_data.head()
# Out:
#       County 2019 Population       State  Cases  Deaths  Biden % votes  \
# 0    Alameda       1,671,329  California  28818   502.0           80.2
# 1     Alpine           1,129  California     41     0.0           64.3
# 2     Amador          39,752  California    487    16.0           36.6
# 3      Butte         219,186  California   3894    59.0           49.4
# 4  Calaveras          45,905  California    478    22.0           36.8
#
#    Trump % votes  % Difference  PoliticalRank
# 0           17.7          62.5              1
# 1           32.3          32.0              1
# 2           60.9         -24.3              5
# 3           47.8           1.6              3
# 4           61.0         -24.2              5

# %% [markdown]
# Here the percentage difference between 'Biden % votes' and 'Trump % votes' was created for every California county, and using that and the defined function above a rank column was created to hold the political ranking of each county.

# %% [markdown]
# ### MS Political Ranks

# %%
MS_data["% Difference"] = MS_data["Biden % votes"] - MS_data["Trump % votes"]
MS_data['PoliticalRank'] = MS_data['% Difference'].apply(political_rank)
MS_data.head()
# Out:
#    County 2019 Population        State  Cases  Deaths  Biden % votes  \
# 0   Adams          30,693  Mississippi   1411    50.0           57.5
# 1  Alcorn          36,953  Mississippi   1496    28.0           17.6
# 2   Amite          12,297  Mississippi    531    14.0           36.4
# 3  Attala          18,174  Mississippi   1122    34.0           40.1
# 4  Benton           8,259  Mississippi    491    17.0           39.1
#
#    Trump % votes  % Difference  PoliticalRank
# 0           41.4          16.1              1
# 1           81.1         -63.5              5
# 2           62.5         -26.1              5
# 3           58.6         -18.5              5
# 4           59.9         -20.8              5

# %% [markdown]
# Here the percentage difference between 'Biden % votes' and 'Trump % votes' was created for every Mississippi county, and using that and the defined function above a rank column was created to hold the political ranking of each county.

# %% [markdown]
# ## Covid Percentages at US State and County Levels

# %% [markdown]
# ### US State Percentages

# %%
def standardize_values(value):
    value = value.replace(',', '')
    value = value.strip()
    return value

# %% [markdown]
# This function standardizes numeric values by removing any commas and whitespaces from each value.

# %%
US_data["2019 Population"] = US_data["2019 Population"].astype(str)
US_data["Cases"] = US_data["Cases"].astype(str)

US_data["2019 Population"] = US_data["2019 Population"].apply(standardize_values)
US_data.head()
# Out:
#         State 2019 Population    Cases  Deaths  Biden % votes  Trump % votes  \
# 0     Alabama         4903185   242874    3572          36.60          62.00
# 1      Alaska          731545    29940     113          43.00          53.10
# 2     Arizona         7278717   318695    6588          49.39          49.08
# 3    Arkansas         3017804   152625    2436          34.80          62.40
# 4  California        39512223  1181420   19033          63.60          34.20
#
#    % Difference  PoliticalRank
# 0        -25.40              5
# 1        -10.10              5
# 2          0.31              3
# 3        -27.60              5
# 4         29.40              1

# %%
US_data["2019 Population"] = US_data["2019 Population"].astype(int)
US_data["Cases"] = US_data["Cases"].astype(int)
US_data["PercentCases"] = (US_data["Cases"] / US_data["2019 Population"]) * 100
US_data.head()
# Out:
#         State  2019 Population    Cases  Deaths  Biden % votes  Trump % votes  \
# 0     Alabama          4903185   242874    3572          36.60          62.00
# 1      Alaska           731545    29940     113          43.00          53.10
# 2     Arizona          7278717   318695    6588          49.39          49.08
# 3    Arkansas          3017804   152625    2436          34.80          62.40
# 4  California         39512223  1181420   19033          63.60          34.20
#
#    % Difference  PoliticalRank  PercentCases
# 0        -25.40              5      4.953393
# 1        -10.10              5      4.092708
# 2          0.31              3      4.378450
# 3        -27.60              5      5.057486
# 4         29.40              1      2.990011

# %% [markdown]
# In the above two cells, the values in the '2019 Population' column were standardized, then the percentage of Covid cases per state was calculated using the 2019 Population as well as the raw number of Covid cases. This became a separate column in the dataframe.

# %% [markdown]
# ## Visualizing the Rate of Infections among US states using a graph

# %% [markdown]
# Now with our cleaned up data we can start creating models to try and predict various variables regarding each state. First lets create a new data frame that contains only the information regarding the political party differences and the Safety Scores of each State

# %%
safety_and_party = policies.merge(US_election, on="State")
safety_and_party =safety_and_party.drop(columns=['Reopening','Stay at Home', 'Traveling Mandatory Quarantine',
                                                            'Business Closures','Gathering Ban',
                                                            'Restaurant Limits','Bar Closures',
                                                            'Mask Requirements','State of Emergency'])

safety_and_party = safety_and_party.rename(columns={"Biden % votes": "Biden", "Trump % votes": "Trump", "% Difference": "Difference"})
safety_and_party.head()
# Out:
#         State  SafetyScore  Biden  Trump  Difference
# 0     Alabama           14  36.60  62.00      -25.40
# 1      Alaska           12  43.00  53.10      -10.10
# 2     Arizona           21  49.39  49.08        0.31
# 3    Arkansas           13  34.80  62.40      -27.60
# 4  California           22  63.60  34.20       29.40

# %% [markdown]
# Now we can create a graph to get a preliminary glimpse at the relationship between Politics and Safety Scores of States.

# %%
a1, b1 = np.polyfit(safety_and_party.SafetyScore, safety_and_party.Difference, 1)

sns.scatterplot(x='SafetyScore', y = 'Difference', data = safety_and_party, s = 100)
xs = np.arange(safety_and_party['SafetyScore'].min(), safety_and_party['Difference'].max())
ys = a1*xs +b1
plt.plot(xs, ys, linewidth=4, label="Model", color="r")
plt.xlabel('SafetyScore')
plt.ylabel('% Difference')

f5 = plt.gcf()

# %% [markdown]
# Looking at this graph, we can see that there is a positive correlation between politics. But there could be more underneath just visualizing the relationship. Let's see if we can create a model that can predict how safe a State is being in its policies based on the difference in political votes compared to other states.

# %%
state_outcome, state_predictors = patsy.dmatrices('SafetyScore ~ Difference', safety_and_party)

state_model = sm.OLS(state_outcome, state_predictors)
state_results = state_model.fit()

# %%
print(state_results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            SafetyScore   R-squared:                       0.385
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     30.05
# Date:                Mon, 14 Dec 2020   Prob (F-statistic):           1.54e-06
# Time:                        14:33:01   Log-Likelihood:                -139.49
# No. Observations:                  50   AIC:                             283.0
# Df Residuals:                      48   BIC:                             286.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     16.7404      0.573     29.226      0.000      15.589      17.892
# ...

# %% [markdown]
# Looking at our results we obtain the following model:
# $$ SafetyScore = 16.7404 + 0.1531 * Difference$$
#
# Here the linear model says that for every 1% difference in Political Rank we can expect a state's Safety Score to be 0.15 units higher than the previous one. This model seems to assist in our initial Hypothesis that as a State is more Democratic leaning, it will have more strict State Policies in safety

# %%
safety_and_cases = policies.merge(US_data, on="State")
safety_and_cases =safety_and_cases.drop(columns=['Reopening','Stay at Home', 'Traveling Mandatory Quarantine',
                                                            'Business Closures','Gathering Ban',
                                                            'Restaurant Limits','Bar Closures',
                                                            'Mask Requirements','State of Emergency'])

safety_and_cases = safety_and_cases.rename(columns={"Biden % votes": "Biden", "Trump % votes": "Trump", "% Difference": "Difference"})
safety_and_cases.head()
# Out:
#         State  SafetyScore  2019 Population    Cases  Deaths  Biden  Trump  \
# 0     Alabama           14          4903185   242874    3572  36.60  62.00
# 1      Alaska           12           731545    29940     113  43.00  53.10
# 2     Arizona           21          7278717   318695    6588  49.39  49.08
# 3    Arkansas           13          3017804   152625    2436  34.80  62.40
# 4  California           22         39512223  1181420   19033  63.60  34.20
#
#    Difference  PoliticalRank  PercentCases
# 0      -25.40              5      4.953393
# 1      -10.10              5      4.092708
# 2        0.31              3      4.378450
# 3      -27.60              5      5.057486
# 4       29.40              1      2.990011

# %% [markdown]
# Now let's look at the relationship between the amount of cases in each state compared to their Safety Score. Now we will plot them on a graph.

# %%
a1, b1 = np.polyfit(safety_and_cases.SafetyScore, safety_and_cases.PercentCases, 1)

sns.scatterplot(x='SafetyScore', y = 'PercentCases', data = safety_and_cases, s = 100)
xs = np.arange(safety_and_cases['SafetyScore'].min(), safety_and_cases['PercentCases'].max())
ys = a1*xs +b1
plt.plot(xs, ys, linewidth=4, label="Model", color="r")
plt.xlabel('SafetyScore')
plt.ylabel('PercentCases')

f5 = plt.gcf()

# %% [markdown]
# Looking initially at this graph we can see that there is a negative correlation between SafetyScore and Percent Cases. This makes sense because States with a higher Safety Scores (i.e. Stricter Safety Policies) would have lower percentages of COVID infections. Now that we have this graph lets create a model to reassure ourselves that this relationship is indeed a negative correlated one. Creating a model that will predict the Safety Score of a State based on its Percentage of COVID cases will tell us if states with more infections will have lower safety scores

# %%
state_outcome, state_predictors = patsy.dmatrices('SafetyScore ~ PercentCases', safety_and_cases)

state_model = sm.OLS(state_outcome, state_predictors)
state_results = state_model.fit()

# %%
print(state_results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            SafetyScore   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                     14.53
# Date:                Mon, 14 Dec 2020   Prob (F-statistic):           0.000393
# Time:                        14:33:02   Log-Likelihood:                -145.04
# No. Observations:                  50   AIC:                             294.1
# Df Residuals:                      48   BIC:                             297.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       22.1080      1.636     13.512      0.000      18.818      25.398
# ...

# %% [markdown]
# Looking at our results we obtain the following model:
# $$ SafetyScore = 22.1080 -1.3486 * Percent Cases$$
#
# This model supports our initial analysis based on the graph. Looking at this Linear Regression Model, we can expect a State's SafetyScore to decrease by 1.34 with each 1% increase in COVID Infections. This is just as we hypothesized. State's with higher rates of infections would have more lax State Policies regarding Social Distancing.

# %%
# see correlations between variables
US_data_corrs = US_data.corr()
US_data_corrs
# Out:
#                  2019 Population     Cases    Deaths  Biden % votes  \
# 2019 Population         1.000000  0.952242  0.824064       0.280039
# Cases                   0.952242  1.000000  0.812482       0.170084
# Deaths                  0.824064  0.812482  1.000000       0.296037
# Biden % votes           0.280039  0.170084  0.296037       1.000000
# Trump % votes          -0.257467 -0.143512 -0.268617      -0.997663
# % Difference            0.268978  0.156970  0.282575       0.999423
# PoliticalRank          -0.232399 -0.114741 -0.278399      -0.931272
# PercentCases           -0.157664  0.018446 -0.115651      -0.581276
#
#                  Trump % votes  % Difference  PoliticalRank  PercentCases
# 2019 Population      -0.257467      0.268978      -0.232399     -0.157664
# Cases                -0.143512      0.156970      -0.114741      0.018446
# Deaths               -0.268617      0.282575      -0.278399     -0.115651
# ...

# %% [markdown]
# The correlations between each variable in the US_data dataframe was calculated. Here if we look at the correlation between Political Rank and Percent cases, we see that there is a value of 0.56. This is a significant value between the two variables which supports our initial hypothesis that the political alignment of a state can have an effect on the amount of COVID infections it has. Additionally, the correlations between our variables show that PercentCases is also correlated with the Percentage of Votes Trump and Biden received highly with 0.58/-0.58 for their values. This shows to us that our created function that assigned Political Rankings to each state is accurate in terms of its relationship and effect on COVID.

# %%
a1, b1 = np.polyfit(US_data_corrs.PoliticalRank, US_data_corrs.PercentCases, 1)

sns.scatterplot(x='PoliticalRank', y = 'PercentCases', data = US_data_corrs, s = 100)
xs = np.arange(US_data_corrs['PoliticalRank'].min(), US_data_corrs['PoliticalRank'].max())
ys = a1*xs +b1
plt.plot(xs, ys, linewidth=4, label="Model", color="r")
plt.xlabel('PoliticalRank')
plt.ylabel('PercentCases')

f5 = plt.gcf()

# %% [markdown]
# Here is a rough visualization of a line of best fit, showing that the more republican a state leans, the higher percentage of Covid cases there are in that state. This is a rough visualization, before we get into the analysis, based purely off of the US_data_corrs dataframe.

# %% [markdown]
# # Analyzing Our Data using Regression Models

# %% [markdown]
# ## Finding a Linear Regression Model predicting The Percentage of Covid Cases using Political Rank of States

# %%
US_data.head()
# Out:
#         State  2019 Population    Cases  Deaths  Biden % votes  Trump % votes  \
# 0     Alabama          4903185   242874    3572          36.60          62.00
# 1      Alaska           731545    29940     113          43.00          53.10
# 2     Arizona          7278717   318695    6588          49.39          49.08
# 3    Arkansas          3017804   152625    2436          34.80          62.40
# 4  California         39512223  1181420   19033          63.60          34.20
#
#    % Difference  PoliticalRank  PercentCases
# 0        -25.40              5      4.953393
# 1        -10.10              5      4.092708
# 2          0.31              3      4.378450
# 3        -27.60              5      5.057486
# 4         29.40              1      2.990011

# %% [markdown]
# Now that we have the data regarding the percentage of Covid infections in each state as well as a relative political ranking that we know is accurate, we can create an OLS model using statsmodel and patsy. We initialize a Linear Regression model fit it, and then view the results. Now that we know from earlier models that the level of a State's safety policies is correlated with their Percentage of COVID cases we want to know if Political Rank is a good predictor for the amount of cases a state will have.

# %%
state_outcome, state_predictors = patsy.dmatrices('PercentCases ~ PoliticalRank', US_data)

state_model = sm.OLS(state_outcome, state_predictors)
state_results = state_model.fit()

# %%
print(state_results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           PercentCases   R-squared:                       0.316
# Model:                            OLS   Adj. R-squared:                  0.301
# Method:                 Least Squares   F-statistic:                     22.14
# Date:                Mon, 14 Dec 2020   Prob (F-statistic):           2.19e-05
# Time:                        14:33:03   Log-Likelihood:                -90.730
# No. Observations:                  50   AIC:                             185.5
# Df Residuals:                      48   BIC:                             189.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         2.4141      0.448      5.394      0.000       1.514       3.314
# ...

# %% [markdown]
# ### Analyzing our Linear Regression Model for US states

# %% [markdown]
# Looking at our results we obtain the following model:
# $$ PercentCases = 2.4141 + 0.5849 * Political Rank$$
#
# This is very similar to the Correlation between Political Rank and PercentCases which was 0.56 so our model is pretty accurate to the data. Our R-squared value is 0.316 which while is not a very high value, we expected that our model would not fully predict the amount of Variance in the data. It is unreasonable to expect that people, especially for a topic as volatile such as presidential elections, to follow a set pattern.
#
# Using an alpha value of 0.05, the parameter for Political Rank is significant so we can include that in our model. This Linear Regression Model does support our initial Hypothesis that States that more Republican Leaning will be more hesitant to engage in more heavily Restrictive Social Distancing Policies which could correlate with a Higher COVID Infection Percentage Rate. Using this Linear Regression Model We can expect that a State's Percentage of Covid Cases to increase by around 0.58% with every increase in Political Rank compared to states with lower Political Ranks. However, while this model does offer an explanation to COVID infection rates, there may be more confounding variables behind the scenes.

# %% [markdown]
# Next, we will compare the analysis done above using the Model to an analysis of the US states using a graph below.

# %% [markdown]
# ### Visualizing our Model regarding the relationship between Covid Rates and Political Rank of States

# %% [markdown]
# Here we will plot a graph to visualize the relationship between COVID cases and a state's political rank based on our model. There is a positive correlation between the two.

# %%
sns.set(font_scale=1) 
plt.xticks(np.arange(1, 6, 1))
plt.scatter(US_data['PoliticalRank'], US_data['PercentCases'], label = 'States');
xs = np.arange(1, 6)
ys = 0.5849 * xs + 2.4141
plt.plot(xs, ys, '--k', linewidth=4, label='Model')

plt.xlabel('Political Rank')
plt.ylabel('Percentage of Covid Cases')
plt.legend();

# %% [markdown]
# ## Finding a Multiple Regression Model predicting The Percentage of Covid Cases using Political Rank of States and Education Rank of States

# %% [markdown]
# Now we want to know if the Education Level of each State also has a role in the amount of cases each state will have. We will need to create a Multiple Regression Model with EducationRank as another predictor. Here we need to add a new column to the US_data dataframe with the data from the State_edu dataframe. Since they are both already in alphabetical order, they are both in the correct index.

# %%
# Adding each state's education rank to the initial US_data data frame
US_data['EducationRank'] = state_edu['Education Rank']
US_data.head()
# Out:
#         State  2019 Population    Cases  Deaths  Biden % votes  Trump % votes  \
# 0     Alabama          4903185   242874    3572          36.60          62.00
# 1      Alaska           731545    29940     113          43.00          53.10
# 2     Arizona          7278717   318695    6588          49.39          49.08
# 3    Arkansas          3017804   152625    2436          34.80          62.40
# 4  California         39512223  1181420   19033          63.60          34.20
#
#    % Difference  PoliticalRank  PercentCases  EducationRank
# 0        -25.40              5      4.953393              1
# 1        -10.10              5      4.092708              2
# 2          0.31              3      4.378450              3
# 3        -27.60              5      5.057486              4
# 4         29.40              1      2.990011              5

# %%
US_data.corr()
# Out:
#                  2019 Population     Cases    Deaths  Biden % votes  \
# 2019 Population         1.000000  0.952242  0.824064       0.280039
# Cases                   0.952242  1.000000  0.812482       0.170084
# Deaths                  0.824064  0.812482  1.000000       0.296037
# Biden % votes           0.280039  0.170084  0.296037       1.000000
# Trump % votes          -0.257467 -0.143512 -0.268617      -0.997663
# % Difference            0.268978  0.156970  0.282575       0.999423
# PoliticalRank          -0.232399 -0.114741 -0.278399      -0.931272
# PercentCases           -0.157664  0.018446 -0.115651      -0.581276
# EducationRank          -0.088960 -0.108351 -0.076081      -0.137423
#
#                  Trump % votes  % Difference  PoliticalRank  PercentCases  \
# 2019 Population      -0.257467      0.268978      -0.232399     -0.157664
# Cases                -0.143512      0.156970      -0.114741      0.018446
# ...

# %% [markdown]
# Looking at the correlation between PercentCases and Education Rank, we have a value of 0.019. This value is less than an alpha value of 0.05 so looking at this initially, we can expect that EducationRank to not have a significant impact on Percentage of COVID cases but we will create a model to test this still.

# %% [markdown]
# ### Creating Our Multiple Regression Model

# %% [markdown]
# Now that we have added in EducationRank to our Dataframe it's time to create a model with it as a Predictor. Here we want to know if EducationRank is a good predictor along with Political Rank to predict the amount of COVID cases a state would have. We do this by creating a Multiple Regression model using OLS.

# %%
state_edu_outcome, state_edu_predictors = patsy.dmatrices('PercentCases ~ PoliticalRank + EducationRank', US_data)

state_edu_model = sm.OLS(state_edu_outcome, state_edu_predictors)
state_edu_results = state_edu_model.fit()

# %%
print(state_edu_results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           PercentCases   R-squared:                       0.316
# Model:                            OLS   Adj. R-squared:                  0.287
# Method:                 Least Squares   F-statistic:                     10.84
# Date:                Mon, 14 Dec 2020   Prob (F-statistic):           0.000134
# Time:                        14:33:04   Log-Likelihood:                -90.727
# No. Observations:                  50   AIC:                             187.5
# Df Residuals:                      47   BIC:                             193.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         2.4419      0.580      4.211      0.000       1.275       3.608
# ...

# %% [markdown]
# ### Analyzing our Multiple Regression model

# %% [markdown]
# Here we see that even by adding in the Education Ranks of States as a 2nd Predictor Value, it had no significant correlation to the Percentage of Covid Cases that we were trying to predict.
#
# We can conclude that the Education Rank of States is insignificant in predicting the Percentage of Covid Cases a State would have. This is slightly surprising to us because we initially believed that less educated individuals would not follow state preventive policies. However, we can surmise that a state's education level is not important in terms of preventive policies. This is probably because the education level of the individuals living in the state would not affect the policies the state governors employ. This Larger Multiple Regression model does not explain more variance in the data as opposed to our previous Linear Regression Model consisting of only Political Rank as the Predictor.

# %% [markdown]
# ### CA Percentages

# %%
CA_data["2019 Population"] = CA_data["2019 Population"].astype(str)
CA_data["Cases"] = CA_data["Cases"].astype(str)

CA_data["2019 Population"] = CA_data["2019 Population"].apply(standardize_values)
CA_data.head()
# Out:
#       County 2019 Population       State  Cases  Deaths  Biden % votes  \
# 0    Alameda         1671329  California  28818   502.0           80.2
# 1     Alpine            1129  California     41     0.0           64.3
# 2     Amador           39752  California    487    16.0           36.6
# 3      Butte          219186  California   3894    59.0           49.4
# 4  Calaveras           45905  California    478    22.0           36.8
#
#    Trump % votes  % Difference  PoliticalRank
# 0           17.7          62.5              1
# 1           32.3          32.0              1
# 2           60.9         -24.3              5
# 3           47.8           1.6              3
# 4           61.0         -24.2              5

# %%
CA_data["2019 Population"] = CA_data["2019 Population"].astype(int)
CA_data["Cases"] = CA_data["Cases"].astype(int)
CA_data["PercentCases"] = (CA_data["Cases"] / CA_data["2019 Population"]) * 100
CA_data.head()
# Out:
#       County  2019 Population       State  Cases  Deaths  Biden % votes  \
# 0    Alameda          1671329  California  28818   502.0           80.2
# 1     Alpine             1129  California     41     0.0           64.3
# 2     Amador            39752  California    487    16.0           36.6
# 3      Butte           219186  California   3894    59.0           49.4
# 4  Calaveras            45905  California    478    22.0           36.8
#
#    Trump % votes  % Difference  PoliticalRank  PercentCases
# 0           17.7          62.5              1      1.724257
# 1           32.3          32.0              1      3.631532
# 2           60.9         -24.3              5      1.225096
# 3           47.8           1.6              3      1.776573
# 4           61.0         -24.2              5      1.041281

# %% [markdown]
# In the above two cells, the values in the '2019 Population' column were standardized, then the percentage of Covid cases per California county was calculated using the 2019 Population as well as the raw number of Covid cases. This became a separate column in the dataframe.

# %% [markdown]
# ## Visualizing Rate of Infections of CA Counties using a Graph

# %%
a1, b1 = np.polyfit(CA_data.PoliticalRank,CA_data.PercentCases, 1)

sns.scatterplot(x='PoliticalRank', y = 'PercentCases', data =CA_data, s = 100)
xs = np.arange(CA_data['PoliticalRank'].min(), CA_data['PoliticalRank'].max())
ys = a1*xs +b1
plt.plot(xs, ys, linewidth=4, label="Model", color="r")
plt.xlabel('PoliticalRank')
plt.ylabel('PercentCases')

f5 = plt.gcf()

# %% [markdown]
# With this visualization of the line of best fit overlapping the scatterplot, there is not much to see in terms of a relationship between the variables, so to look into it deeper, we will proceed with a linear regression analysis.

# %%
# see correlations between variables
CA_data_corrs = CA_data.corr()
CA_data_corrs
# Out:
#                  2019 Population     Cases    Deaths  Biden % votes  \
# 2019 Population         1.000000  0.977400  0.964565       0.285093
# Cases                   0.977400  1.000000  0.992808       0.213776
# Deaths                  0.964565  0.992808  1.000000       0.197233
# Biden % votes           0.285093  0.213776  0.197233       1.000000
# Trump % votes          -0.280516 -0.209813 -0.193594      -0.999704
# % Difference            0.282827  0.211812  0.195430       0.999926
# PoliticalRank          -0.303922 -0.240065 -0.214447      -0.884398
# PercentCases            0.126074  0.197749  0.179280      -0.044705
#
#                  Trump % votes  % Difference  PoliticalRank  PercentCases
# 2019 Population      -0.280516      0.282827      -0.303922      0.126074
# Cases                -0.209813      0.211812      -0.240065      0.197749
# Deaths               -0.193594      0.195430      -0.214447      0.179280
# ...

# %% [markdown]
# The correlations between each variable in the CA_data dataframe was calculated. The correlation between PercentCases and Political rank is -0.05 which is very low and is also an inverse correlation. This initially tells us that the two variables are not very correlated and that one would decrease when the other increases which goes against our initial hypothesis that more Republican counties would have higher cases. However, this data does support our hypothesis of California counties as we predicted that the CA counties would follow the overall state trend in the number of cases regardless of the individual political leanings.

# %% [markdown]
# ## Finding A Linear Correlation Model Predicting The Percentage of Covid Cases and Political Rank for CA Counties

# %% [markdown]
# Just like we did with the individual states, we will create a Linear Regression Model predicting the amount of COVID cases using Political Rank. However, this time we are analyzing California's individual counties because California is a primarily Democratic State.

# %%
CA_outcome, CA_predictors = patsy.dmatrices('PercentCases ~ PoliticalRank', CA_data)

CA_model = sm.OLS(CA_outcome, CA_predictors)
CA_results = CA_model.fit()

# %%
print(CA_results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           PercentCases   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                    0.1775
# Date:                Mon, 14 Dec 2020   Prob (F-statistic):              0.675
# Time:                        14:33:05   Log-Likelihood:                -105.91
# No. Observations:                  58   AIC:                             215.8
# Df Residuals:                      56   BIC:                             219.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         2.7087      0.356      7.603      0.000       1.995       3.422
# ...

# %% [markdown]
# ### Analyzing our CA Counties Linear Regression Model

# %% [markdown]
# Looking at our results we obtain the following model:
# $$ PercentCases = 2.7087 - 0.0464 * Political Rank$$
#
# Here the model for Linear Regression for California Counties does not seem to indicate a significant change in Covid infection rates among counties based on their Political Ranking. When there is a change in Political Rank there does not seem to be a big change in COVID Infection Rate. The R-squared value is 0.003 which is extremely low. We can surmise that this model does not accurately explain the variance in the data.
#
# We imagine that this is due to California being primarily Democratic, so its state policies are similarly enforced throughout the Counties. Since the state employs mostly democratic preventive policies, we could be incorrect in assuming that the more Republican counties would not follow the COVID preventive policies.

# %% [markdown]
# Next, we will compare the analysis done above using the Model to an analysis of CA counties using a graph below.

# %% [markdown]
# ### Visualizing our Model between The Percentage of Covid Cases and Political Ranks of CA Counties

# %%
plt.xticks(np.arange(1, 6, 1))
plt.scatter(CA_data['PoliticalRank'], CA_data['PercentCases'], label = 'Counties');
xs = np.arange(1,6)
ys = -0.0464 * xs + 2.7087
plt.plot(xs, ys, '--k', linewidth=4, label='Model')

plt.xlabel('Political Rank')
plt.ylabel('Percentage of Covid Cases')
plt.legend();

# %% [markdown]
# ### MS Percentages

# %%
MS_data["2019 Population"] = MS_data["2019 Population"].astype(str)
MS_data["Cases"] = MS_data["Cases"].astype(str)

MS_data["2019 Population"] = MS_data["2019 Population"].apply(standardize_values)
MS_data.head()
# Out:
#    County 2019 Population        State Cases  Deaths  Biden % votes  \
# 0   Adams           30693  Mississippi  1411    50.0           57.5
# 1  Alcorn           36953  Mississippi  1496    28.0           17.6
# 2   Amite           12297  Mississippi   531    14.0           36.4
# 3  Attala           18174  Mississippi  1122    34.0           40.1
# 4  Benton            8259  Mississippi   491    17.0           39.1
#
#    Trump % votes  % Difference  PoliticalRank
# 0           41.4          16.1              1
# 1           81.1         -63.5              5
# 2           62.5         -26.1              5
# 3           58.6         -18.5              5
# 4           59.9         -20.8              5

# %%
MS_data["2019 Population"] = MS_data["2019 Population"].astype(int)
MS_data["Cases"] = MS_data["Cases"].astype(int)
MS_data["PercentCases"] = (MS_data["Cases"] / MS_data["2019 Population"]) * 100
MS_data.head()
# Out:
#    County  2019 Population        State  Cases  Deaths  Biden % votes  \
# 0   Adams            30693  Mississippi   1411    50.0           57.5
# 1  Alcorn            36953  Mississippi   1496    28.0           17.6
# 2   Amite            12297  Mississippi    531    14.0           36.4
# 3  Attala            18174  Mississippi   1122    34.0           40.1
# 4  Benton             8259  Mississippi    491    17.0           39.1
#
#    Trump % votes  % Difference  PoliticalRank  PercentCases
# 0           41.4          16.1              1      4.597139
# 1           81.1         -63.5              5      4.048386
# 2           62.5         -26.1              5      4.318126
# 3           58.6         -18.5              5      6.173655
# 4           59.9         -20.8              5      5.945030

# %% [markdown]
# In the above two cells, the values in the '2019 Population' column were standardized, then the percentage of Covid cases per Mississippi county was calculated using the 2019 Population as well as the raw number of Covid cases. This became a separate column in the dataframe.

# %% [markdown]
# ##  Visualizing Rate of Infections of MS Counties using a Graph

# %%
a1, b1 = np.polyfit(MS_data.PoliticalRank,MS_data.PercentCases, 1)

sns.scatterplot(x='PoliticalRank', y = 'PercentCases', data =MS_data, s = 100)
xs = np.arange(MS_data['PoliticalRank'].min(), MS_data['PoliticalRank'].max())
ys = a1*xs +b1
plt.plot(xs, ys, linewidth=4, label="Model", color="r")
plt.xlabel('PoliticalRank')
plt.ylabel('PercentCases')

f5 = plt.gcf()

# %% [markdown]
# With this visualization, we see a slight trend, opposite to what we expected, with the Covid cases decreasing with political rank. To further explore this visualization, we have conducted a linear regression analysis below.

# %%
# see correlations between variables
MS_data_corrs = MS_data.corr()
MS_data_corrs
# Out:
#                  2019 Population     Cases    Deaths  Biden % votes  \
# 2019 Population         1.000000  0.964774  0.807798      -0.059691
# Cases                   0.964774  1.000000  0.843996      -0.016563
# Deaths                  0.807798  0.843996  1.000000       0.063959
# Biden % votes          -0.059691 -0.016563  0.063959       1.000000
# Trump % votes           0.053297  0.009981 -0.067514      -0.999848
# % Difference           -0.056491 -0.013267  0.065742       0.999962
# PoliticalRank           0.135710  0.109968  0.028892      -0.882942
# PercentCases           -0.380337 -0.216808 -0.135353       0.385633
#
#                  Trump % votes  % Difference  PoliticalRank  PercentCases
# 2019 Population       0.053297     -0.056491       0.135710     -0.380337
# Cases                 0.009981     -0.013267       0.109968     -0.216808
# Deaths               -0.067514      0.065742       0.028892     -0.135353
# ...

# %% [markdown]
# The correlations between each variable in the MS_data dataframe was calculated. Here the correlation between the PercentCases and Political Rank is -0.32. This also goes against our initial hypothesis that more Republican Counties would have higher rates of COVID infection. Since this correlation also went against our initial hypothesis for California, we are beginning to think that our model is less accurate at the County level compared to the state level.

# %% [markdown]
# ## Finding A Linear Correlation Model Predicting The Percentage of Covid Cases and Political Rank for MS Counties

# %% [markdown]
# Just like we did with the individual states, we will create a Linear Regression Model predicting the amount of COVID cases using Political Rank. However, this time we are analyzing Mississippi's individual counties because California is a primarily Republican State. We want to see if there is a difference between California and Mississippi.

# %%
MS_outcome, MS_predictors = patsy.dmatrices('PercentCases ~ PoliticalRank', MS_data)

MS_model = sm.OLS(MS_outcome, MS_predictors)
MS_results = MS_model.fit()

# %%
print(MS_results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           PercentCases   R-squared:                       0.104
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     9.287
# Date:                Mon, 14 Dec 2020   Prob (F-statistic):            0.00313
# Time:                        14:33:07   Log-Likelihood:                -127.81
# No. Observations:                  82   AIC:                             259.6
# Df Residuals:                      80   BIC:                             264.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         6.3803      0.305     20.899      0.000       5.773       6.988
# ...

# %% [markdown]
# ### Analyzing our MS Counties Linear Regression model

# %% [markdown]
# Looking at our results we obtain the following model:
# $$ PercentCases = 6.3803 - 0.2269 * Political Rank$$
#
# Here for the Mississippi Counties the model seems to predict that the % of COVID cases decreases by 0.22% with an increase in Political Rank according to the data. However, looking at the data the intercept for Mississippi is much higher compared to California (6.38 compared to 2.70). The large intercept indicates that the average infection rate for a County in Mississippi is larger than California's average. The R-squared value is 0.1 which is extremely low even assuming that people are unpredictable.
#
# Considering the fact that Mississippi is a Republican State, the fact that it has a much higher intercept for Percentage of Covid Cases could show a correlation between Republican political policies on prevention and rate of COVID Infections.

# %% [markdown]
# ### Visualizing our Model between The Percentage of Covid Cases and Political Ranks of MS Counties

# %%
plt.xticks(np.arange(1, 6, 1))
plt.scatter(MS_data['PoliticalRank'], MS_data['PercentCases'], label = 'Counties');
xs = np.arange(1,6)
ys = -0.2269 * xs + 6.3803
plt.plot(xs, ys, '--k', linewidth=4, label='Model')

plt.xlabel('Political Rank')
plt.ylabel('Percentage of Covid Cases')
plt.legend();

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp; We as college students, and especially as citizens of the United States, are aware that our country can be very divided on the two topics of politics and ways to combat COVID-19. However, our intent with this project is not to place blame on people who follow a particular political stance and hold them responsible for spreading COVID-19. Data that suggests that Republicans are less likely to trust scientific evidence could be used to attack Republicans, which is not what our intent is. We want to label our research question and hypothesis so that it remains neutral towards any political parties, perhaps by examining what policies they employ against Coronavirus and how useful they are in limiting the spread of the disease. When evaluating the data, we want to ensure that we do not infer causation between political parties and high cases of COVID-19. Taking into consideration latent variables such as the populations of each state could help us from drawing inaccurate conclusions.
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp; The data we collect for our project will only be from public sources and will protect every individual’s privacy. The 2020 election results sources will only list the overall political leaning of each state and county and not every individual’s own political inclination. Each state’s Covid safety policies are all shared public data which everyone can access, so using it in our project would not personally affect the people living in these states. However, we have considered how the data and project could unintentionally result in negative consequences on states that have higher cases of COVID-19. These states could come under attack from media outlets to further their political propaganda. We aim to prevent this by structuring our question to be neutral towards all political parties so that it cannot be interpreted as attacking the character of any parties.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp; Our overall goal with this project was to merge data about education levels, 2020 election results, and adherence to Covid-19 safety guidelines about each state in an effort to find out if these factors have an impact on the amount of Covid-19 cases in each US state.
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp; Looking at the models we derived from our data we saw that there was indeed a correlation between the percentage of COVID cases a state had and its Political Ranking. Additionally, there was a correlation between the Safety Scores of each state and their Political Rankings as well. This tells us that the level of strictness in Safety Policies each state enforces is related to the overall political alignment of states. Furthermore, we initially thought that a state’s overall education level would impact the state’s amount of Covid-19 cases, but there was not a confounding variable in our results. Therefore, we concluded that there was a correlation in how Political Rank predicts the percentage of infections each state had. A more Republican state would have more relaxed state policies regarding social distancing which we concluded would lead to a higher percentage of infections. More Democratic states would enforce harsher safety policies which leads to a lower amount of cases. This analysis works for individual states, but it was not as accurate in predicting individual counties within the states.
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp; Some analysis limitations due to time restrictions included not being able to further break down which specific safety guidelines had greater effects on reducing the number of Covid-19 cases. We also would have liked to have broken down the election results by demographic to further analyze how certain groups voted and their likelihood of being affected by Covid=19. We could have also utilized the NYT API to obtain election results data instead of creating our own datasets based off of their maps and charts. In terms of visualizations, we could have implemented more maps, especially of states counties, in relation to political rank. Currently, we have a plot, but for those who are not very familiar with each state and the counties within each state, a map may have helped with spatial visualization.
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp; This project is extremely relevant to our society as we are still in the midst of a pandemic. The results seen here may be able to have some effect on states with less strict guidelines turning to states with stricter guidelines and fewer cases. Ultimately, it is important for all states to adopt as many safety measures as possible to mitigate the spread of the virus.

# %% [markdown]
# # Team Contributions

# %% [markdown]
# - Everyone:
#     - Overall topic for project, research question, hypothesis, conclusion
# - Member 1 and 2:
#     - Background and prior work section. Finding and cleaning all datasets. Wrote dataset summaries. Started data analysis for safety scores and political rank. Helped clean data visualizations.
# - Member 3:
#     - Project proposal data section. Helped separate the data frames of each state. Helped create data visualizations. Helped with making models and with analysis.
# - Huy Huynh:
#     - Project proposal Privacy/Ethics section. Created Models to analyze the data for the states and the two individual states’ counties. Analyzed models and compared them to initial hypothesis. Created Visualizations for each model.
# - Member 5:
#     - Made California county population dataset. Edited ethics section.
